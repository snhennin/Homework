# %% [markdown]
# ## Our project majority involves looking at publication bias of the comprehensive database that consists with 225 major depressive disorder clinical data studies with structural imaging of brain measures. In this meta-analysis study, researchers compared healthy brain structures with MDD brain structures. The publication bias mainly focuses on the overall results of studies findings in the Caudate, Putamen, Globus Pallidus, Thalamus, Temporal, and Hippocampus. Having a generalized look at the publication bias helps us determine the accuracy and precision of this overall database.

# %% [markdown]
# ### Much of the evidence for the role of specific brain areas in psychiatry comes from "brain imaging," which involves various ways of looking at the brain. Some technologies like PET imaging and functional MRI can measure the activity of the brain either at rest or while a person does certain tasks. Other technologies, like traditional MRI, measure the brain's structure—its size and shape.
# ### Compared with the structure of a healthy brain, MDD was associated with lateral ventricle enlargement; larger cerebrospinal fluid volume; and smaller volumes of the basal ganglia, thalamus, hippocampus, frontal lobe, orbitofrontal cortex, and gyrus rectus. Patients during depressive episodes had significantly smaller hippocampal volume than patients during remission. This can be used in the future to aid diagnoses and further lead to personalizing treatment based off predictions of antidepressant responsiveness in the brain.

# %%
#Here I am importing the packages needed for our meta-analysis

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #This package is for making plots
import xlrd # This is the excel package

# %% [markdown]
# ### For the coding portion of our project. We wanted to check the publication bias for the data we have collected. The first thing we had to do was collect the size of the patient group and the control group. I put that in a comparison chart with the volumetric mean on the left and right side of the brain, as well as the standard deviation. Then I calculated the ratio using the average patient mean and control mean. Then I solved for the pooled standard error and standard error for each study.. Below are the individual tables for each brain region.

# %%
#This is the table for the Caudate section of the brain. This data comes from our original dataset from the Major Depressive 
#Disorder Neuroimaging Database. It includes data from the right region of the brain, the left region of the brain, and what
#we calculated to complete our analysis.

caudate = pd.read_excel('Project Data Collection.xlsx', sheet_name='Comparisons', skip_rows=1, header=1, index_col=0).iloc[:8]

caudate.head()
# Out:
#       Patient Numbers Control Numbers Left Patient Mean (mL)  \
# Study
# 1                  38              20                    4.6
# 2                  24              24                   3.34
# 3                  16              16                  2.668
# 4                   9              29                  4.267
# 5                  25              48                   2.63
#
#       Left Control Mean (mL) Left Patient SD Left Control SD  \
# Study
# 1                        4.6             0.7             0.6
# 2                       3.19            0.69            0.59
# 3                      2.767            0.71           0.571
# 4                      4.336           0.506           0.447
# 5                       2.82            0.42             0.5
#
#       Right Patient Mean (mL) Right Control Mean (mL) Right Patient SD  \
# Study
# 1                         4.4                     4.4              0.7
# ...

# %%
#This is the table for the Putamen section of the brain.

putamen = pd.read_excel('Project Data Collection.xlsx', sheet_name='Comparisons', skip_rows=12, header=12, index_col=0).iloc[:6]

putamen.head()
# Out:
#       Patient Numbers Control Numbers Left Patient Mean (mL)  \
# Study
# 1                  41              44                    3.8
# 2                  24              24                   3.86
# 3                  25              48                   3.05
# 4                  27              26                   3.58
# 5                 170              83                   3.61
#
#       Left Control Mean (mL) Left Patient SD Left Control SD  \
# Study
# 1                        4.9             1.2            1.45
# 2                       3.79            0.55            0.48
# 3                       3.23            0.84            0.84
# 4                        3.8            0.62            0.58
# 5                       3.65            0.76            0.63
#
#       Right Patient Mean (mL) Right Control Mean (mL) Right Patient SD  \
# Study
# 1                         3.7                     4.9              1.2
# ...

# %%
#This is the table for the Globus Pallidus section of the brain

globus_pallidus = pd.read_excel('Project Data Collection.xlsx', sheet_name='Comparisons', skip_rows=21, header=21, index_col=0).iloc[:2]

globus_pallidus.head()
# Out:
#       Patient Numbers Control Numbers Left Patient Mean (mL)  \
# Study
# 1                  25              48                   1.48
# 3                  26              31                  1.659
#
#       Left Control Mean (mL) Left Patient SD Left Control SD  \
# Study
# 1                       1.44            0.18            0.22
# 3                      1.718           1.718           0.252
#
#       Right Patient Mean (mL) Right Control Mean (mL) Right Patient SD  \
# Study
# 1                        1.51                    1.56             0.23
# 3                       1.658                   1.781            0.287
#
#       Right Control SD Average Patient Mean Average Control Mean Mean Ratio  \
# Study
# 1                 0.26                1.495                  1.5   0.996667
# 3                0.279               1.6585               1.7495   0.947985
#
#       Average Patient SD Average Control SD  Pooled SD Standard Error
# Study
# ...

# %%
#This is the table for the Thalamus section of the brain

thalamus = pd.read_excel('Project Data Collection.xlsx', sheet_name='Comparisons', skip_rows=26, header=26, index_col=0).iloc[:1]

thalamus.head()
# Out:
#       Patient Numbers Control Numbers Left Patient Mean (mL)  \
# Study
# 5                  17              39                    3.6
#
#       Left Control Mean (mL) Left Patient SD Left Control SD  \
# Study
# 5                       3.37            0.89            0.88
#
#       Right Patient Mean (mL) Right Control Mean (mL) Right Patient SD  \
# Study
# 5                        3.65                    3.48             0.88
#
#       Right Control SD Average Patient Mean Average Control Mean Mean Ratio  \
# Study
# 5                 1.02                3.625                3.425    1.05839
#
#       Average Patient SD Average Control SD Pooled SD Standard Error
# Study
# 5                  0.885               0.95  0.126722       0.036829

# %%
#This is the table for the Temporal section of the brain

temporal = pd.read_excel('Project Data Collection.xlsx', sheet_name='Comparisons', skip_rows=30, header=30, index_col=0).iloc[:5]

temporal.head()
# Out:
#       Patient Numbers Control Numbers Left Patient Mean (mL)  \
# Study
# 1                  19              13                  46.54
# 2                  16              16                 17.931
# 3                   9               9                 73.375
# 4                  31              31                  71.39
# 5                  38              33                 15.396
#
#       Left Control Mean (mL) Left Patient SD Left Control SD  \
# Study
# 1                      47.39            7.03             6.9
# 2                     18.227            4.17           1.791
# 3                     79.352           5.499           6.478
# 4                       69.9            8.29            9.16
# 5                      16.66           1.586           1.935
#
#       Right Patient Mean (mL) Right Control Mean (mL) Right Patient SD  \
# Study
# 1                       46.55                   43.37              6.3
# ...

# %%
#This is the table for the Hippocampus section of the brain

hippo = pd.read_excel('Project Data Collection.xlsx', sheet_name='Comparisons', skip_rows=38, header=38, index_col=0).iloc[:42]

hippo.head()
# Out:
#        Patient Numbers  Control Numbers  Left Patient Mean (mL)  \
# Study
# 1.0               40.0             46.0                   1.745
# 2.0               16.0             16.0                   0.940
# 3.0               38.0             20.0                   2.640
# 4.0               25.0             15.0                   2.170
# 5.0               23.0             23.0                   3.150
#
#        Left Control Mean (mL)  Left Patient SD  Left Control SD  \
# Study
# 1.0                     1.853            0.380            0.348
# 2.0                     1.166            0.208            0.248
# 3.0                     2.460            0.550            0.380
# 4.0                     2.130            0.260            0.270
# 5.0                     3.240            0.390            0.440
#
#        Right Patient Mean (mL)  Right Control Mean (mL)  Right Patient SD  \
# Study
# 1.0                      1.742                    1.843             0.345
# ...

# %% [markdown]
# ### Using the mean ratio and the standard error, I created a funnel plot in order to determine if there was a publication bias with any of our sources. In a funnel plot, you are looking for a triangle shape on an inverted y-axis. The reason we are expecting a funnel shape is because it is more likely for there to be a large amount of less precise data compared to the very precise data.

# %%
#Loading the data from the excel spreadsheet
wb = xlrd.open_workbook('Project Data Collection.xlsx', on_demand = True)
ws = workbook.sheet_by_name('Comparisons')

#Plotting the data from the caudate section of the brain
x1 = caudate.loc[:,'Mean Ratio']
y1 = caudate.loc[:,'Standard Error']

#Plotting the data from the putamen section of the brain
x2 = putamen.loc[:,'Mean Ratio']
y2 = putamen.loc[:,'Standard Error']

#Plotting the data from the globus pallidus section of the brain
x3 = globus_pallidus.loc[:,'Mean Ratio']
y3 = globus_pallidus.loc[:,'Standard Error']

#Plotting the data from the thalamus section of the brain
x4 = thalamus.loc[:,'Mean Ratio']
y4 = thalamus.loc[:,'Standard Error']

#Plotting the data from the temporal section of the brain
x5 = temporal.loc[:,'Mean Ratio']
y5 = temporal.loc[:,'Standard Error']

#Plotting the data from the hippocampus section of the brain
x6 = hippo.loc[:,'Mean Ratio']
y6 = hippo.loc[:,'Standard Error']


#Create the funnel tringle
plt.plot([0.96,0.96],[0,0.1], 'k')
plt.plot([0.6,0.96],[0.1,0], 'k')
plt.plot([0.96,1.32],[0,0.1], 'k')

#Plot the brain sections
plt.scatter(x1,y1, color="red")
plt.scatter(x2,y2, color="darkorange")
plt.scatter(x3,y3, color="gold")
plt.scatter(x4,y4, color="limegreen")
plt.scatter(x5,y5, color="dodgerblue")
plt.scatter(x6,y6, color="orchid")

#Clean up the plot
plt.ylim(0,0.06)
plt.xlabel('Study Results', fontsize=12)
plt.ylabel('Less precision <--> More precision', fontsize=12)
plt.title('Publication Bias', fontsize=18)

plt.legend(['Avg. Mean Ratio','Funnel Boundary','Funnel Boundary','Caudate','Putamen','Globus Pallidus','Thalamus','Temporal','Hippocampus'], loc='upper right')
plt.gca().invert_yaxis()

fig1 = plt.gcf()
plt.show()
plt.draw
fig1.savefig('publication_bias.png', dpi=100)

# %% [markdown]
# ### Since it is difficult to see all the study points, I also made graphs showing the publication bias for each individual region.

# %%
#The funnel plot for the caudate region.

#Loading the data from the excel spreadsheet
wb = xlrd.open_workbook('Project Data Collection.xlsx', on_demand = True)
ws = workbook.sheet_by_name('Comparisons')

#Plotting the data from the caudate section of the brain
x = caudate.loc[:,'Mean Ratio']
y = caudate.loc[:,'Standard Error']

#Create the funnel tringle
plt.plot([0.96,0.96],[0,0.1], 'k')
plt.plot([0.6,0.96],[0.1,0], 'k')
plt.plot([0.96,1.32],[0,0.1], 'k')

#Plot the brain section
plt.scatter(x,y, color="red")

#Clean up the plot
plt.ylim(0,0.05)
plt.xlabel('Study Results', fontsize=12)
plt.ylabel('Less precision <--> More precision', fontsize=12)
plt.title('Caudate Publication Bias', fontsize=18)

plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# For the caudate, it appears that almost all of the studies are in the funnel plot, meaning that they most likely aren't bias. There is one study that has a significantly low mean ratio, meaning that the control mean is higher than the patient mean. It also has a very low standard error.

# %%
#The funnel plot for the putamen region.

#Loading the data from the excel spreadsheet
wb = xlrd.open_workbook('Project Data Collection.xlsx', on_demand = True)
ws = workbook.sheet_by_name('Comparisons')

#Plotting the data from the caudate section of the brain
x = putamen.loc[:,'Mean Ratio']
y = putamen.loc[:,'Standard Error']

#Create the funnel tringle
plt.plot([0.96,0.96],[0,0.1], 'k')
plt.plot([0.6,0.96],[0.1,0], 'k')
plt.plot([0.96,1.32],[0,0.1], 'k')

#Plot the brain section
plt.scatter(x,y, color="darkorange")

#Clean up the plot
plt.ylim(0,0.04)
plt.xlabel('Study Results', fontsize=12)
plt.ylabel('Less precision <--> More precision', fontsize=12)
plt.title('Putamen Publication Bias', fontsize=18)

plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# Similar to the caudate region, most of the studies seem to be free of bias, with two outliers.

# %%
#The funnel plot for the globus pallidus region.

#Loading the data from the excel spreadsheet
wb = xlrd.open_workbook('Project Data Collection.xlsx', on_demand = True)
ws = workbook.sheet_by_name('Comparisons')

#Plotting the data from the caudate section of the brain
x = globus_pallidus.loc[:,'Mean Ratio']
y = globus_pallidus.loc[:,'Standard Error']

#Create the funnel tringle
plt.plot([0.96,0.96],[0,0.1], 'k')
plt.plot([0.6,0.96],[0.1,0], 'k')
plt.plot([0.96,1.32],[0,0.1], 'k')

#Plot the brain section
plt.scatter(x,y, color="gold")

#Clean up the plot
plt.ylim(0,0.04)
plt.xlabel('Study Results', fontsize=12)
plt.ylabel('Less precision <--> More precision', fontsize=12)
plt.title('Globus Pallidus Publication Bias', fontsize=18)

plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# The results for the globus pallidus are inconclusive. While one lies inside the triangle, the other does not. In order to accurately get results for this section, it would be beneficial to obtain more studies that take place in the globus pallidus.

# %%
#The funnel plot for the thalamus region.

#Loading the data from the excel spreadsheet
wb = xlrd.open_workbook('Project Data Collection.xlsx', on_demand = True)
ws = workbook.sheet_by_name('Comparisons')

#Plotting the data from the caudate section of the brain
x = thalamus.loc[:,'Mean Ratio']
y = thalamus.loc[:,'Standard Error']

#Create the funnel tringle
plt.plot([0.96,0.96],[0,0.1], 'k')
plt.plot([0.6,0.96],[0.1,0], 'k')
plt.plot([0.96,1.32],[0,0.1], 'k')

#Plot the brain section
plt.scatter(x,y, color="limegreen")

#Clean up the plot
plt.ylim(0,0.05)
plt.xlabel('Study Results', fontsize=12)
plt.ylabel('Less precision <--> More precision', fontsize=12)
plt.title('Thalamus Publication Bias', fontsize=18)

plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# Similar to the globus pallibus section, there are not enough studies on this region of the brain to get an accurate result with abundant confidence.

# %%
#The funnel plot for the temporal region.

#Loading the data from the excel spreadsheet
wb = xlrd.open_workbook('Project Data Collection.xlsx', on_demand = True)
ws = workbook.sheet_by_name('Comparisons')

#Plotting the data from the caudate section of the brain
x = temporal.loc[:,'Mean Ratio']
y = temporal.loc[:,'Standard Error']

#Create the funnel tringle
plt.plot([0.96,0.96],[0,1], 'k')
plt.plot([-1.92,0.96],[1,0], 'k')
plt.plot([0.96,3.84],[0,1], 'k')

#Plot the brain section
plt.scatter(x,y, color="dodgerblue")

#Clean up the plot
plt.ylim(0,0.8)
plt.xlabel('Study Results', fontsize=12)
plt.ylabel('Less precision <--> More precision', fontsize=12)
plt.title('Temporal Publication Bias', fontsize=18)

plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# Out of all of our results, the temporal studies look to be the most accurate. The closer the points are to the average mean ratio line, the more likely there is no bias. Every study of the temporal region lies on the line or just off of it. They also have varying standard errors, showing they most likely didn't manufacture biased standard errors.

# %%
#The funnel plot for the hippocampus region.

#Loading the data from the excel spreadsheet
wb = xlrd.open_workbook('Project Data Collection.xlsx', on_demand = True)
ws = workbook.sheet_by_name('Comparisons')

#Plotting the data from the caudate section of the brain
x = hippo.loc[:,'Mean Ratio']
y = hippo.loc[:,'Standard Error']

#Create the funnel tringle
plt.plot([0.96,0.96],[0,0.1], 'k')
plt.plot([0.6,0.96],[0.1,0], 'k')
plt.plot([0.96,1.32],[0,0.1], 'k')

#Plot the brain section
plt.scatter(x,y, color="orchid")

#Clean up the plot
plt.ylim(0,0.06)
plt.xlabel('Study Results', fontsize=12)
plt.ylabel('Less precision <--> More precision', fontsize=12)
plt.title('Hippocampus Publication Bias', fontsize=18)

plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# The hippocampus was the brain region was the section that had the most studies done about it, with a total of 42. There shows to be great variation in the results of these studies. Depression has been known to have a shrinking effect on the hippoampus section of the brain. This could explain the large amount of studies that show a smaller mean ratio. Although the very low standard error for this studies is suspicious, given that they lie outside the funnel

# %% [markdown]
# ### The results of our study show that there is a larger amount of very precise data compared to the less precise data, as seen by the large amount of data points that lie outside of the triangle, mostly in the hippocampus section. Considering that this section had the largest study size, it is reasonable that it has the most biased publications. The brain section that appears to be the most accurate is the temporal section. In a funnel plot, you are looking for symmetry. The number of studies should be thin near the top of the graph, wide near the bottom of the graph, and should tend towards the average mean ratio line. Outside of the hippocampus section, there appears to be very limited outliers.
